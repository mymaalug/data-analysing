# %% [markdown]
# # Name: Maalug Mary Yabia
#
# # Student ID: 10971409

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the dataset into a Pandas DataFrame
df = pd.read_csv('data.csv')

# %%
df
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
# Dropping the duplicate rows
df = df.drop_duplicates()

# %%
# Checking for duplicates
print(df.duplicated().sum())
# Out:
# 0

# %%
df.shape
# Out:
# (1601, 13)

# %%
# Checking for null values
print(df.isnull().sum())
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             1
# residual sugar          0
# chlorides               3
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
fixed_acidity_mean = df['fixed acidity'].mean()
citric_acid_mean = df['citric acid'].mean()
chlorides_mean = df['chlorides'].mean()
free_sulfur_dioxide_mean = df['free sulfur dioxide'].mean()
total_sulfur_dioxide_mean = df['total sulfur dioxide'].mean()
density_mean = df['density'].mean()
pH_mean = df['pH'].mean()
quality_mean = df['quality'].mean()

# %% [markdown]
# ##### Reason for replacing null values with the mean of each column
# If you have a large dataset with many missing values, you can increase the accuracy of your analysis by filling them in with the mean of the appropriate column. This is due to the fact that the mean is a representative number that can provide a good estimate of the missing value.

# %%
# Filling null values with mean
df['fixed acidity'] = df['fixed acidity'].fillna(fixed_acidity_mean)
df['citric acid'] = df['citric acid'].fillna(citric_acid_mean)
df['chlorides'] = df['chlorides'].fillna(chlorides_mean)
df['free sulfur dioxide'] = df['free sulfur dioxide'].fillna(free_sulfur_dioxide_mean)
df['total sulfur dioxide'] = df['total sulfur dioxide'].fillna(total_sulfur_dioxide_mean)
df['density'] = df['density'].fillna(density_mean)
df['pH'] = df['pH'].fillna(pH_mean)
df['quality'] = df['quality'].fillna(quality_mean)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1601 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1601 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1601 non-null   float64
#  6   free sulfur dioxide   1601 non-null   float64
#  7   total sulfur dioxide  1601 non-null   float64
#  8   density               1601 non-null   float64
#  9   pH                    1601 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1601 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 175.1 KB

# %%
# Descriptive statistics of numerical columns
print(df.describe())
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1601.000000    1601.000000       1601.000000  1601.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.739495          0.178981     0.194684
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1601.000000  1601.000000          1601.000000           1601.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047032            10.455218             32.967416
# ...

# %%
df['volatile acidity'].mode()
# Out:
# 0    0.6
# Name: volatile acidity, dtype: float64

# %%
df['residual sugar'].mode()
# Out:
# 0    2.0
# Name: residual sugar, dtype: float64

# %%
df['sulphates'].median()
# Out:
# 0.62

# %%
df['alcohol'].median()
# Out:
# 10.2

# %%
# Frequency distribution of categorical columns
df['quality'].value_counts()
# Out:
# 5.00000    681
# 6.00000    639
# 7.00000    199
# 4.00000     53
# 8.00000     18
# 3.00000     10
# 5.63625      1
# Name: quality, dtype: int64

# %%
df['citric acid'].value_counts()
# Out:
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     39
#        ...
# 0.72      1
# 1.00      1
# 0.75      1
# 0.62      1
# 0.78      1
# Name: citric acid, Length: 81, dtype: int64

# %%
df['residual sugar'].value_counts()
# Out:
# 2.00     156
# 2.20     131
# 1.80     129
# 2.10     128
# 1.90     118
#         ...
# 4.25       1
# 2.85       1
# 3.45       1
# 2.35       1
# 13.90      1
# Name: residual sugar, Length: 91, dtype: int64

# %%
df['volatile acidity'].value_counts()
# Out:
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.580    38
#          ..
# 1.035     1
# 0.565     1
# 1.130     1
# 1.115     1
# 1.090     1
# Name: volatile acidity, Length: 143, dtype: int64

# %%
df['pH'].value_counts()
# Out:
# 3.30    58
# 3.36    56
# 3.26    53
# 3.38    48
# 3.39    48
#         ..
# 2.74     1
# 3.75     1
# 3.70     1
# 3.85     1
# 2.90     1
# Name: pH, Length: 90, dtype: int64

# %%
df['fixed acidity'].value_counts()
# Out:
# 7.200000     68
# 7.100000     57
# 7.800000     53
# 7.500000     52
# 7.000000     50
#              ..
# 13.500000     1
# 13.800000     1
# 13.400000     1
# 4.700000      1
# 8.319875      1
# Name: fixed acidity, Length: 97, dtype: int64

# %%
# Skewness and kurtosis of numerical columns
print(df['pH'].skew())
# Out:
# 0.19393840603188678

# %%
print(df['pH'].kurt())
# Out:
# 0.8117136202927506

# %%
print(df['quality'].skew())
# Out:
# 0.21710674611048034

# %%
print(df['quality'].kurt())
# Out:
# 0.29977290390526523

# %%
df.corr()
# Out:
#                             ID  fixed acidity  volatile acidity  citric acid  \
# ID                    1.000000      -0.267899         -0.009544    -0.153294
# fixed acidity        -0.267899       1.000000         -0.255557     0.670856
# volatile acidity     -0.009544      -0.255557          1.000000    -0.552909
# citric acid          -0.153294       0.670856         -0.552909     1.000000
# residual sugar       -0.031589       0.114595          0.001877     0.143517
# chlorides            -0.119131       0.093472          0.060748     0.203981
# free sulfur dioxide   0.091145      -0.152932         -0.010591    -0.061252
# total sulfur dioxide -0.113809      -0.113325          0.076247     0.036014
# density              -0.368725       0.667693          0.022753     0.364104
# pH                    0.135082      -0.682452          0.235182    -0.542637
# sulphates            -0.124243       0.182291         -0.261364     0.312839
# ...

# %%
# Correlation matrix
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot: >

# %%
numerical_cols = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']

# %%
# Create subplots for each column
fig, axs = plt.subplots(nrows=4, ncols=3, figsize=(15, 15))
# Flatten the axes to make it easier to iterate over them
axs = axs.flatten()
# Create histogram for each column
for i, col in enumerate(numerical_cols):
    plt.subplots_adjust(wspace=0.5, hspace=0.5)
    axs[i].hist(df[col], bins=10)
    axs[i].set_xlabel(col)
    axs[i].set_ylabel('Count')
# Remove any unused subplots
for i in range(len(numerical_cols), len(axs)):
    fig.delaxes(axs[i])
fig.suptitle('Histograms Of Red Wine Characteristics')
plt.show()

# %%
#  A figure and an array of axis objects
fig, axs = plt.subplots(4, 3, figsize=(15, 15))
axs = axs.flatten()
for i, col in enumerate(numerical_cols):
    category_counts = df[col].value_counts()
    axs[i].pie(category_counts.values, labels=category_counts.index, autopct='%1.1f%%')
    axs[i].set_title(col)
    fig.suptitle('Distribution of Characteristics')
plt.show()

# %%
fig, axs = plt.subplots(4, 3, figsize=(20, 20))
axs = axs.flatten()
for i, column in enumerate(numerical_cols):
    axs[i].bar(df[column].value_counts().index, df[column].value_counts().values)
    axs[i].set_title(column)
    fig.suptitle('Distribution of Characteristics')
plt.show()
